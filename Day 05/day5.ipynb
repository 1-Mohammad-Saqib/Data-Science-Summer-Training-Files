# %%
import numpy as np

# %%
c = np.array([1,2,3])
d = np.array([2,4,5])

# %%
c + d
# Out:
# array([3, 6, 8])

# %%
a = np.array([[1,2,3],[2,3,4]])
b = np.array([[2,3,4],[3,4,6]])

# %%
a * b
# Out:
# array([[ 2,  6, 12],
#        [ 6, 12, 24]])

# %%
a + b
# Out:
# array([[ 3,  5,  7],
#        [ 5,  7, 10]])

# %%
a - b
# Out:
# array([[-1, -1, -1],
#        [-1, -1, -2]])

# %%
np.dot(a,np.transpose(b))
# Out:
# array([[20, 29],
#        [29, 42]])
