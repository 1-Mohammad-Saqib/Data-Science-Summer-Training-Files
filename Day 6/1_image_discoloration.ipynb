# %%
pip install pillow
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

img = Image.open("1.jpg")

img = np.array(img)

img[:,:,0] = np.clip(img[:,:,0] + 10,10,200)

plt.imshow(img)
# plt.axis("off")
plt.show()

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
df = pd.DataFrame({"Name":["Saqib","Sahil","Sachin","Zoya"],"Marks":[10,20,10,10]
                  })

# %%
df
# Out:
#      Name  Marks
# 0   Saqib     10
# 1   Sahil     20
# 2  Sachin     10
# 3    Zoya     10

# %%
df.
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_24940\3262616258.py in ?()
# ----> 1 df.duplicate()
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6317             and name not in self._accessors
#    6318             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6319         ):
#    6320             return self[name]
# -> 6321         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'duplicate'
